# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt


with open('be1f0e06-635e-4f30-8d9f-678f22b7eeb3.pkl', 'rb') as f:
    data = pickle.loads(f.read())
time_step = data['Timestep']
mean_reward = data['mean']
best_reward = data['best']

plt.figure()
plt.plot(time_step, mean_reward)
plt.plot(time_step, best_reward)
plt.title('Mean 100-Episode Reward Vs. Best Reward of Deep Q-Learning', fontsize=11)
plt.xlabel('Timesteps')
plt.ylabel('Mean Episode Reward')
plt.legend(['Mean', 'Best Mean'])
ax = plt.gca()
ax.xaxis.get_major_formatter().set_powerlimits((0,0))
plt.show()

# %%
'''
    data = {'Timestep': np.array(self.timestep_log),
            'mean': np.array(self.mean_reward_log),
            'best': np.array(self.best_reward_log)}
'''

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt


with open('14b2210d-164f-4a24-bc9a-ae229e88a42f.pkl', 'rb') as f:
    data = pickle.loads(f.read())
time_step = data['Timestep']
mean_reward = data['mean']
best_reward = data['best']

plt.figure()
plt.plot(time_step, mean_reward)
plt.plot(time_step, best_reward)
plt.title('Mean 100-Episode Reward Vs. Best Reward of Deep Q-Learning', fontsize=11)
plt.xlabel('Timesteps')
plt.ylabel('Mean Episode Reward')
plt.legend(['Mean', 'Best Mean'])
ax = plt.gca()
ax.xaxis.get_major_formatter().set_powerlimits((0,0))
plt.show()
